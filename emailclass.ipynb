# %%
import nltk

nltk.download('punkt_tab')


nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/devendraruparel/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/devendraruparel/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/devendraruparel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/devendraruparel/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/devendraruparel/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/devendraruparel/nltk_data...
# True

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

text = "Customer is unhappy with the delayed delivery service."

tokens = word_tokenize(text.lower())
stop_words = set(stopwords.words('english'))

filtered = [w for w in tokens if w.isalnum() and w not in stop_words]

print(filtered)
# Out:
# ['customer', 'unhappy', 'delayed', 'delivery', 'service']

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()

words = ["delayed", "delivery", "services"]
stemmed = [ps.stem(w) for w in words]

print(stemmed)
# Out:
# ['delay', 'deliveri', 'servic']

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/devendraruparel/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
import nltk

text = "Customer requested refund for damaged product"

tokens = nltk.word_tokenize(text)
pos = nltk.pos_tag(tokens)

print(pos)
# Out:
# [('Customer', 'NNP'), ('requested', 'VBD'), ('refund', 'NN'), ('for', 'IN'), ('damaged', 'VBN'), ('product', 'NN')]

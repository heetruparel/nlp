# %%
#importing
import nltk

nltk.download('punkt_tab')
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')

# %%
#Tokenization + Stopword Removal
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

text = "Customer is unhappy with the delayed delivery service."

tokens = word_tokenize(text.lower())
stop_words = set(stopwords.words('english'))

filtered = [w for w in tokens if w.isalnum() and w not in stop_words]

print(filtered)

# %%
#Stemming
from nltk.stem import PorterStemmer

ps = PorterStemmer()

words = ["delayed", "delivery", "services"]
stemmed = [ps.stem(w) for w in words]

print(stemmed)

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')

# %%
#POS Tagging
import nltk

text = "Customer requested refund for damaged product"

tokens = nltk.word_tokenize(text)
pos = nltk.pos_tag(tokens)

print(pos)
